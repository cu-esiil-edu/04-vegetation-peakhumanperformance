# %%
pip install osmnx geopandas matplotlib shapely
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import osmnx as ox
import geopandas as gpd
import matplotlib.pyplot as plt

ox.settings.use_cache = True
ox.settings.log_console = True

# %%
# search Arizona for anything with "Gila River" in the name
results = ox.features_from_place(
    "Arizona, USA",
    {"name": True}  # pull all named features
)

gila = results[results["name"].str.contains("Gila River", case=False, na=False)]

print(gila[["name", "boundary", "landuse", "geometry"]])
# Out:
# /opt/conda/lib/python3.11/site-packages/osmnx/_overpass.py:271: UserWarning: This area is 122 times your configured Overpass max query area size. It will automatically be divided up into multiple sub-queries accordingly. This may take a long time.
#   multi_poly_proj = utils_geo._consolidate_subdivide_geometry(poly_proj)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 2
#       1 # search Arizona for anything with "Gila River" in the name
# ----> 2 results = ox.features_from_place(
#       3     "Arizona, USA",
#       4     {"name": True}  # pull all named features
#       5 )
#       7 gila = results[results["name"].str.contains("Gila River", case=False, na=False)]
#       9 print(gila[["name", "boundary", "landuse", "geometry"]])
#
# File /opt/conda/lib/python3.11/site-packages/osmnx/features.py:279, in features_from_place(query, tags, which_result)
# ...

# %%
# 2. filter for Gila River
gdf_boundary = gdf[gdf["name"].str.contains("Gila River", case=False, na=False)]

# 3. reproject
gdf_boundary = gdf_boundary.to_crs(3857)
boundary_polygon = gdf_boundary.geometry.unary_union
